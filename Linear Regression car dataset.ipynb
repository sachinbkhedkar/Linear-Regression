# %%
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
import numpy as np

# %%
car = pd.read_csv(r"C:\Users\hp\Downloads\car_price.csv")

# %%
car.head(5)
# Out:
#    symboling normalized_losses Fuel_type make num_of_doors   aspiration  \
# 0          3                 ?       gas  std          two  convertible
# 1          3                 ?       gas  std          two  convertible
# 2          1                 ?       gas  std          two    hatchback
# 3          2               164       gas  std         four        sedan
# 4          2               164       gas  std         four        sedan
#
#   wheel_base engine_location  drive_wheels   body_style  length  width  \
# 0        rwd           front          88.6  alfa-romero   168.8   64.1
# 1        rwd           front          88.6  alfa-romero   168.8   64.1
# 2        rwd           front          94.5  alfa-romero   171.2   65.5
# 3        fwd           front          99.8         audi   176.6   66.2
# 4        4wd           front          99.4         audi   176.6   66.4
#
#    height  curb_weight engine_type num_of_cylinders  engine_size fuel_system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression_ratio horsepower peak_rpm  city_mpg  highway_mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19    3.4               10.0        102     5500        24           30
# 4  3.19    3.4                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
car.shape
# Out:
# (205, 26)

# %%
car.columns
# Out:
# Index(['symboling', 'normalized_losses', 'Fuel_type', 'make', 'num_of_doors',
#        'aspiration', 'wheel_base', 'engine_location', 'drive_wheels',
#        'body_style', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    object
#  2   Fuel_type          205 non-null    object
#  3   make               205 non-null    object
#  4   num_of_doors       205 non-null    object
#  5   aspiration         205 non-null    object
#  6   wheel_base         205 non-null    object
#  7   engine_location    205 non-null    object
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
#  16  engine_size        205 non-null    int64
#  17  fuel_system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression_ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak_rpm           205 non-null    object
#  23  city_mpg           205 non-null    int64
#  24  highway_mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
car.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# Fuel_type            0
# make                 0
# num_of_doors         0
# aspiration           0
# wheel_base           0
# engine_location      0
# drive_wheels         0
# body_style           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
car.duplicated().sum()
# Out:
# 0

# %%
car = car.replace({'?':np.nan})

# %%
car.isnull().sum()
# Out:
# symboling             0
# normalized_losses    41
# Fuel_type             0
# make                  0
# num_of_doors          2
# aspiration            0
# wheel_base            0
# engine_location       0
# drive_wheels          0
# body_style            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num_of_cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 4
# dtype: int64

# %%
car.isnull().sum()[car.isnull().sum()>0]
# Out:
# normalized_losses    41
# num_of_doors          2
# bore                  4
# stroke                4
# horsepower            2
# peak_rpm              2
# price                 4
# dtype: int64

# %%
car.normalized_losses = car.normalized_losses.astype('float')
car.normalized_losses = car.normalized_losses.fillna(car.normalized_losses.mean())

# %%
car.num_of_doors = car.num_of_doors.fillna('four')

# %%
car.bore = car.bore.astype('float')
car.bore = car.bore.fillna(car.bore.mean())

# %%
car.stroke = car.stroke.astype('float')
car.stroke = car.stroke.fillna(car.stroke.mean())

# %%
car.horsepower = car.horsepower.astype('float')
car.horsepower = car.horsepower.fillna(car.horsepower.mean())

# %%
car.peak_rpm = car.peak_rpm.astype('float')
car.peak_rpm = car.peak_rpm.fillna(car.peak_rpm.mean())

# %%
car.price = car.price.astype('float')

# %%
car.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# Fuel_type            0
# make                 0
# num_of_doors         0
# aspiration           0
# wheel_base           0
# engine_location      0
# drive_wheels         0
# body_style           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                4
# dtype: int64

# %%
car = car.dropna()

# %%
car.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# Fuel_type            0
# make                 0
# num_of_doors         0
# aspiration           0
# wheel_base           0
# engine_location      0
# drive_wheels         0
# body_style           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
car[car.select_dtypes(include=['object']).columns] =car[car.select_dtypes(include=['object']).columns].apply(le.fit_transform)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    float64
#  2   Fuel_type          201 non-null    int32
#  3   make               201 non-null    int32
#  4   num_of_doors       201 non-null    int32
#  5   aspiration         201 non-null    int32
#  6   wheel_base         201 non-null    int32
#  7   engine_location    201 non-null    int32
#  8   drive_wheels       201 non-null    float64
#  9   body_style         201 non-null    int32
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb_weight        201 non-null    int64
#  14  engine_type        201 non-null    int32
#  15  num_of_cylinders   201 non-null    int32
#  16  engine_size        201 non-null    int64
#  17  fuel_system        201 non-null    int32
#  18  bore               201 non-null    float64
#  19  stroke             201 non-null    float64
#  20  compression_ratio  201 non-null    float64
#  21  horsepower         201 non-null    float64
#  22  peak_rpm           201 non-null    float64
#  23  city_mpg           201 non-null    int64
#  24  highway_mpg        201 non-null    int64
#  25  price              201 non-null    float64
# dtypes: float64(11), int32(10), int64(5)
# memory usage: 34.5 KB

# %% [markdown]
# # Sampling

# %%
from sklearn.model_selection import train_test_split

# %%
car = df1

# %%
car_train, car_test = train_test_split(car,test_size=.2)

# %%
car_train.shape
# Out:
# (149, 26)

# %%
car_test.shape
# Out:
# (38, 26)

# %%
car_train_y = car_train.iloc[:,-1:]
car_test_y = car_test.iloc[:,-1:]

# %%
car_train_y.head(5)
# Out:
#        price
# 155   8778.0
# 59    8845.0
# 68   28248.0
# 28    8921.0
# 54    7395.0

# %%
car_test_y.head(5)
# Out:
#        price
# 142   7775.0
# 197  16515.0
# 102  14399.0
# 110  13860.0
# 106  18399.0

# %%
car_train_x = car_train.iloc[:,:-1:]
car_test_x = car_test.iloc[:,:-1:]

# %%
car_train_x.head(5)
# Out:
#      symboling  normalized_losses  Fuel_type  make  num_of_doors  aspiration  \
# 155          0               91.0          1     0             0           4
# 59           1              129.0          1     0             1           2
# 68          -1               93.0          0     1             0           4
# 28          -1              110.0          1     0             0           4
# 54           1              113.0          1     0             0           3
#
#      wheel_base  engine_location  drive_wheels  body_style  length  width  \
# 155           0                0          95.7          19   169.7   63.6
# 59            1                0          98.8           8   177.8   66.5
# 68            2                0         110.0           9   190.9   70.3
# 28            1                0         103.3           4   174.6   64.6
# 54            1                0          93.1           8   166.8   64.2
#
#      height  curb_weight  engine_type  num_of_cylinders  engine_size  \
# 155    59.1         3110            2                 2           92
# 59     53.7         2385            2                 2          122
# 68     58.7         3750            2                 1          183
# 28     59.8         2535            2                 2          122
# 54     54.1         1950            2                 2           91
#
#      fuel_system  bore  stroke  compression_ratio  horsepower  peak_rpm  \
# 155            1  3.05    3.03                9.0        62.0    4800.0
# 59             1  3.39    3.39                8.6        84.0    4800.0
# 68             3  3.58    3.64               21.5       123.0    4350.0
# 28             1  3.34    3.46                8.5        88.0    5000.0
# 54             1  3.08    3.15                9.0        68.0    5000.0
#
#      city_mpg  highway_mpg
# 155        27           32
# 59         26           32
# 68         22           25
# 28         24           30
# 54         31           38

# %% [markdown]
# # Bulding The Model

# %%
from sklearn.linear_model import LinearRegression

# %%
linereg = LinearRegression()

# %%
linereg.fit(car_train_x,car_train_y)
# Out:
# LinearRegression()

# %%
Rsquare = linereg.score(car_train_x,car_train_y)
Rsquare
# Out:
# 0.8700942551176072

# %%
N = car_train_x.shape[0]
K = car_train_x.shape[1]

# %%
adjusted_Rsquare = 1-(1-Rsquare)*(N-1)/(N-K-1)
adjusted_Rsquare
# Out:
# 0.843690648434194

# %%
linereg.coef_ # Bita Values
# Out:
# array([[-5.58838319e+01,  2.80840545e+00,  1.68359049e+04,
#          2.28186111e+03, -7.58911725e+02, -5.18368708e+02,
#          1.07816368e+03,  7.14450721e-12,  9.90500840e+01,
#         -1.81283512e+02, -3.43344610e+01,  4.53386165e+02,
#          1.23316438e+02,  3.72129917e+00,  2.55592054e+02,
#         -8.90967480e+01,  3.37423386e+01,  2.45328529e+02,
#         -1.59470273e+03, -1.66501019e+03,  1.35681209e+03,
#          6.64787752e+00, -2.77001639e-01, -2.20926960e+02,
#          8.08091745e+01]])

# %%
linereg.intercept_ # Bita not values
# Out:
# array([-55473.85524465])

# %%
pred_train = linereg.predict(car_train_x)
pred_test = linereg.predict(car_test_x)

# %%
#  Lets Check The Assumption.
#  Assumption on the train data.

# %%
err_train = car_train_y - pred_train
err_train
# Out:
#            price
# 155  -359.415099
# 59  -1368.397011
# 68   3756.696846
# 28  -2881.630385
# 54    176.001103
# 162  2458.090112
# 170 -1750.594133
# 178   114.926531
# 103 -4231.255967
# 174 -2483.903505
# 172  2976.216167
# 75  -1875.079478
# 149  1303.494009
# 175  -480.193956
# 193  2140.222468
# 196  1102.406280
# 13   2781.814586
# 66   3689.795606
# 41   1262.542327
# 77   -851.720436
# 201   309.871242
# 21  -1010.696581
# 82   -574.101658
# 76   -471.832419
# 50  -1534.275508
# 122   329.123474
# 165  1292.307784
# 37  -1341.206936
# 198  2212.007437
# 169 -1965.899131
# 3    -665.425364
# 134  -991.086995
# 79  -1846.874040
# 92     45.484549
# 166   883.693605
# 179  -814.852396
# 30   2505.803257
# 195 -1561.544369
# 107 -4600.911232
# 91    661.971824
# 84    955.764546
# 203  1736.317247
# 98    822.844834
# 150   499.502555
# 115   -75.582686
# 1    1477.910725
# 22  -1275.262698
# 67   1688.129606
# 65   3163.158213
# 163  1298.764617
# 62   -540.508251
# 69   4572.048140
# 56    189.286417
# 80   -863.935540
# 29   -901.659466
# 94   1189.168951
# 34   -314.375139
# 81    194.064445
# 38   -338.435792
# 10   2991.972059
# 96    572.681676
# 26   -763.901396
# 188  -324.117203
# 171 -1012.470895
# 112 -1624.052480
# 131   390.552457
# 20   -932.940344
# 200   596.692933
# 185  -350.054424
# 145   568.585921
# 108 -5119.381026
# 24  -2580.401523
# 104 -1081.590420
# 78   -594.998386
# 111 -2777.297119
# 33   -854.834352
# 189  2983.713724
# 95   1042.540271
# 116  -574.052480
# 204  3044.208596
# 18   3261.214386
# 113 -2021.008527
# 151   481.932434
# 148  -314.354269
# 173  -517.431788
# 144  1023.092976
# 176   824.858314
# 152     2.562459
# 40   1767.861613
# 97   1690.359641
# 194 -2077.930799
# 191   934.711811
# 58   2022.366747
# 99   -264.600466
# 8    1943.450874
# 202  2870.351534
# 192   242.643599
# 61    381.602989
# 124  -901.648284
# 123  -951.745640
# 177   616.068880
# 118   656.603691
# 12   3610.397765
# 100   935.636824
# 51  -1016.225760
# 180 -1050.276278
# 138 -1051.914741
# 35   -722.587481
# 164   830.150438
# 63  -1426.187395
# 167 -3983.333548
# 114 -2156.294131
# 46  -3428.845858
# 89   -380.110500
# 93   1088.736530
# 2   -2468.112896
# 156   532.409872
# 53   -585.127538
# 6   -1121.617902
# 141  -947.499784
# 161  1106.704788
# 119  -923.143448
# 101 -4716.665882
# 130  -859.100792
# 183   121.385845
# 186  -284.496272
# 19   -933.580854
# 32  -1861.316971
# 42    606.561074
# 117   425.409194
# 160  2243.356921
# 135  2381.599468
# 182  -488.778679
# 39   -653.232690
# 168 -2778.448352
# 121   433.764615
# 181  -519.706101
# 43  -2656.414441
# 5    1286.800056
# 27  -2421.415374
# 105   -34.476041
# 190  2980.274507
# 88    -95.917999
# 187 -1812.981348
# 146  -386.812619
# 4    2997.381931
# 14   4491.688253
# 132  -752.598539
# 83   1354.371042

# %%
np.mean(err_train)
# Out:
# -1.992342756098549e-11

# %%
err_test = car_test_y - pred_test
err_test
# Out:
#            price
# 142 -1137.230045
# 197  1729.612198
# 102 -4013.856698
# 110 -5166.622677
# 106  -865.004296
# 85  -2019.195793
# 184  -960.218949
# 36   -790.071913
# 139   202.651041
# 25  -1680.901396
# 90   1995.483123
# 55   -710.713583
# 143   -32.550958
# 64   -114.696447
# 31    559.072058
# 136  3095.762292
# 120  -784.416835
# 52   -334.832256
# 137  3253.391428
# 0   -1527.089275
# 86   -968.047760
# 154  1840.134272
# 159  -580.177783
# 23  -2487.841634
# 199  2820.606859
# 153   310.079178
# 57   1970.679921
# 157   194.508075
# 87  -2232.310581
# 158    28.720715
# 133  -723.958684
# 60  -2290.508251
# 11   2616.292671
# 125  6109.637329
# 140  1065.968065
# 7     298.510494
# 147   201.913321
# 109 -4666.255517

# %%
mse = np.mean(np.square(err_test))
mse
# Out:
# 4872617.558025253

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 2207.4006337829237

# %%
mape = np.mean(np.abs(err_test * 100 / car_test_y))
mape
# Out:
# 14.424292843077174

# %%
np.mean(err_test)
# Out:
# -152.45995510202576

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(err_train, '*')

# %%
plt.hist(err_train,bins=20,edgecolor = 'k');

# %%
import seaborn as sns

# %%
pred_actual_df = pd.DataFrame()
pred_actual_df['Actual'] =car_train_y
pred_actual_df['Predict'] =pred_train
sns.jointplot(data=pred_actual_df,x = 'Actual',y = 'Predict',kind='reg')

# %%
# remove outliers
def remove_outliers(df,col,k):
    mean = df[col].mean()
    global df1
    sd = df[col].std()
    final_list = [x for x in df[col] if (x > mean-k *sd)]
    final_list = [x for x in final_list if (x< mean + k *sd)]
    df1 = df.loc[df[col].isin(final_list)]; print(df1.shape)
    print("Number of outliers remove -->",df.shape[0] - df1.shape[0])

# %%
remove_outliers(car,'price',2)
# Out:
# (178, 26)
# Number of outliers remove --> 9
