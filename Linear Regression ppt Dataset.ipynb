# %%
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
import numpy as np

# %%
ppt = pd.read_csv(r"D:\Machine Learning Dataset\Property_Price_Train.csv")

# %%
ppt.head(5)
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type Lot_Configuration Property_Slope  \
# 0            Reg          Lvl       AllPub                 I             GS
# 1            Reg          Lvl       AllPub              FR2P             GS
# 2            IR1          Lvl       AllPub                 I             GS
# 3            IR1          Lvl       AllPub                 C             GS
# 4            IR1          Lvl       AllPub              FR2P             GS
#
# ...

# %%
ppt.shape
# Out:
# (1459, 81)

# %%
ppt.columns
# Out:
# Index(['Id', 'Building_Class', 'Zoning_Class', 'Lot_Extent', 'Lot_Size',
#        'Road_Type', 'Lane_Type', 'Property_Shape', 'Land_Outline',
#        'Utility_Type', 'Lot_Configuration', 'Property_Slope', 'Neighborhood',
#        'Condition1', 'Condition2', 'House_Type', 'House_Design',
#        'Overall_Material', 'House_Condition', 'Construction_Year',
#        'Remodel_Year', 'Roof_Design', 'Roof_Quality', 'Exterior1st',
#        'Exterior2nd', 'Brick_Veneer_Type', 'Brick_Veneer_Area',
#        'Exterior_Material', 'Exterior_Condition', 'Foundation_Type',
#        'Basement_Height', 'Basement_Condition', 'Exposure_Level',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'Total_Basement_Area', 'Heating_Type', 'Heating_Quality',
#        'Air_Conditioning', 'Electrical_System', 'First_Floor_Area',
#        'Second_Floor_Area', 'LowQualFinSF', 'Grade_Living_Area',
#        'Underground_Full_Bathroom', 'Underground_Half_Bathroom',
# ...

# %%
ppt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         1459 non-null   int64
#  1   Building_Class             1459 non-null   int64
#  2   Zoning_Class               1459 non-null   object
#  3   Lot_Extent                 1200 non-null   float64
#  4   Lot_Size                   1459 non-null   int64
#  5   Road_Type                  1459 non-null   object
#  6   Lane_Type                  91 non-null     object
#  7   Property_Shape             1459 non-null   object
#  8   Land_Outline               1459 non-null   object
#  9   Utility_Type               1459 non-null   object
#  10  Lot_Configuration          1459 non-null   object
#  11  Property_Slope             1459 non-null   object
#  12  Neighborhood               1459 non-null   object
# ...

# %%
ppt.isnull().sum()
# Out:
# Id                              0
# Building_Class                  0
# Zoning_Class                    0
# Lot_Extent                    259
# Lot_Size                        0
# Road_Type                       0
# Lane_Type                    1368
# Property_Shape                  0
# Land_Outline                    0
# Utility_Type                    0
# Lot_Configuration               0
# Property_Slope                  0
# Neighborhood                    0
# Condition1                      0
# Condition2                      0
# House_Type                      0
# House_Design                    0
# Overall_Material                0
# House_Condition                 0
# Construction_Year               0
# Remodel_Year                    0
# Roof_Design                     0
# Roof_Quality                    0
# Exterior1st                     0
# Exterior2nd                     0
# Brick_Veneer_Type             871
# Brick_Veneer_Area               8
# ...

# %%
ppt.isnull().sum()[ppt.isnull().sum()>0]
# Out:
# Lot_Extent                259
# Lane_Type                1368
# Brick_Veneer_Type         871
# Brick_Veneer_Area           8
# Basement_Height            37
# Basement_Condition         37
# Exposure_Level             38
# BsmtFinType1               37
# BsmtFinType2               38
# Electrical_System           1
# Fireplace_Quality         689
# Garage                     81
# Garage_Built_Year          81
# Garage_Finish_Year         81
# Garage_Quality             81
# Garage_Condition           81
# Pool_Quality             1452
# Fence_Quality            1178
# Miscellaneous_Feature    1405
# dtype: int64

# %%
len(ppt.isnull().sum()[ppt.isnull().sum()>0])
# Out:
# 19

# %%
ppt.isnull().sum()[ppt.isnull().sum()*100/ppt.shape[0] >40 ]
# Out:
# Lane_Type                1368
# Brick_Veneer_Type         871
# Fireplace_Quality         689
# Pool_Quality             1452
# Fence_Quality            1178
# Miscellaneous_Feature    1405
# dtype: int64

# %%
ppt.Lot_Extent=ppt.Lot_Extent.fillna(ppt.Lot_Extent.mean())
ppt.Brick_Veneer_Type = ppt.Brick_Veneer_Type.fillna('None')
ppt.Brick_Veneer_Area =ppt.Brick_Veneer_Area.fillna(ppt.Brick_Veneer_Area.mean())
ppt.Basement_Height =ppt.Basement_Height.fillna('TA')
ppt.Basement_Condition = ppt.Basement_Condition.fillna('TA')
ppt.Exposure_Level =ppt.Exposure_Level.fillna('No')
ppt.BsmtFinType1 = ppt.BsmtFinType1.fillna('Unf')
ppt.BsmtFinType2 = ppt.BsmtFinType2.fillna('Unf')
ppt.Electrical_System = ppt.Electrical_System.fillna('Sbrkr')
ppt.Fireplace_Quality = ppt.Fireplace_Quality.fillna('Gd')
ppt.Garage = ppt.Garage.fillna('Attchd')
ppt.Garage_Built_Year = ppt.Garage_Built_Year.fillna(ppt.Garage_Built_Year.mean())
ppt.Garage_Finish_Year = ppt.Garage_Finish_Year.fillna('Unf')
ppt.Garage_Quality = ppt.Garage_Quality.fillna('TA')
ppt.Garage_Condition = ppt.Garage_Condition.fillna('TA')

# %%
ppt.isnull().sum()[ppt.isnull().sum()>0]
# Out:
# Lane_Type                1368
# Pool_Quality             1452
# Fence_Quality            1178
# Miscellaneous_Feature    1405
# dtype: int64

# %%
ppt.Pool_Quality = ppt.Pool_Quality.fillna('N')

# %%
ppt=ppt.drop(['Fence_Quality','Miscellaneous_Feature'],axis=1)

# %%
ppt.isnull().sum()[ppt.isnull().sum()>0]
# Out:
# Lane_Type    1368
# dtype: int64

# %%
ppt = ppt.iloc[:,1::]

# %%
ppt.head()
# Out:
#    Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0              60          RLD        65.0      8450     Paved       NaN
# 1              20          RLD        80.0      9600     Paved       NaN
# 2              60          RLD        68.0     11250     Paved       NaN
# 3              70          RLD        60.0      9550     Paved       NaN
# 4              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type Lot_Configuration Property_Slope  \
# 0            Reg          Lvl       AllPub                 I             GS
# 1            Reg          Lvl       AllPub              FR2P             GS
# 2            IR1          Lvl       AllPub                 I             GS
# 3            IR1          Lvl       AllPub                 C             GS
# 4            IR1          Lvl       AllPub              FR2P             GS
#
#   Neighborhood Condition1 Condition2 House_Type House_Design  \
# ...

# %%
#  Label Encoder
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
ppt[ppt.select_dtypes(include=['object']).columns] = ppt[ppt.select_dtypes(include=['object']).columns].apply(le.fit_transform)

# %%
ppt.head()
# Out:
#    Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Road_Type  Lane_Type  \
# 0              60             3        65.0      8450          1          2
# 1              20             3        80.0      9600          1          2
# 2              60             3        68.0     11250          1          2
# 3              70             3        60.0      9550          1          2
# 4              60             3        84.0     14260          1          2
#
#    Property_Shape  Land_Outline  Utility_Type  Lot_Configuration  \
# 0               3             3             0                  4
# 1               3             3             0                  2
# 2               0             3             0                  4
# 3               0             3             0                  0
# 4               0             3             0                  2
#
#    Property_Slope  Neighborhood  Condition1  Condition2  House_Type  \
# ...

# %%
ppt.select_dtypes(include='object').columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# # Sampling

# %%
from sklearn.model_selection import train_test_split

# %%
ppt = df1

# %%
ppt_train, ppt_test = train_test_split(ppt,test_size= .2)

# %%
ppt_train.shape
# Out:
# (1116, 78)

# %%
1459*80/100
# Out:
# 1167.2

# %%
ppt_test.shape
# Out:
# (280, 78)

# %%
ppt_train_x = ppt_train.iloc[:,:-1]
ppt_train_y = ppt_train.iloc[:,-1]

# %%
ppt_train_y.head()
# Out:
# 939    244400
# 701    140000
# 627    153000
# 141    260000
# 962    155000
# Name: Sale_Price, dtype: int64

# %%
ppt_train_x.head()
# Out:
#      Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Road_Type  Lane_Type  \
# 939              70             3   70.045833     24090          1          2
# 701              20             3   80.000000      9600          1          2
# 627              80             3   80.000000      9600          1          2
# 141              20             3   78.000000     11645          1          2
# 962             160             3   24.000000      2308          1          2
#
#      Property_Shape  Land_Outline  Utility_Type  Lot_Configuration  \
# 939               3             3             0                  4
# 701               3             3             0                  4
# 627               3             3             0                  4
# 141               3             3             0                  4
# 962               3             3             0                  0
#
#      Property_Slope  Neighborhood  Condition1  Condition2  House_Type  \
# ...

# %%
ppt_test_x = ppt_test.iloc[:,:-1]
ppt_test_y = ppt_test.iloc[:,-1]

# %%
ppt_test_y.head()
# Out:
# 1383    112000
# 420     206300
# 1029    118000
# 310     165600
# 1144     80000
# Name: Sale_Price, dtype: int64

# %%
ppt_test_x.head(4)
# Out:
#       Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Road_Type  \
# 1383              30             3   70.045833     25339          1
# 420               90             4   78.000000      7060          1
# 1029             160             4   21.000000      1680          1
# 310               60             3   70.045833      7685          1
#
#       Lane_Type  Property_Shape  Land_Outline  Utility_Type  \
# 1383          2               3             3             0
# 420           2               3             3             0
# 1029          2               3             3             0
# 310           2               0             3             0
#
#       Lot_Configuration  Property_Slope  Neighborhood  Condition1  Condition2  \
# 1383                  4               0            19           2           2
# 420                   4               0            11           2           2
# 1029                  4               0             2           2           2
# ...

# %% [markdown]
# # Bulding The Model

# %%
from sklearn.linear_model import LinearRegression

# %%
linereg = LinearRegression()

# %%
linereg
# Out:
# LinearRegression()

# %%
linereg.fit(ppt_train_x,ppt_train_y)
# Out:
# LinearRegression()

# %%
Rsquare = linereg.score(ppt_train_x,ppt_train_y)
Rsquare
# Out:
# 0.8544442302967575

# %%
N = ppt_train_x.shape[0]
K = ppt_train_x.shape[1]

# %%
adjusted_Rsquare = 1-(1-Rsquare)*(N-1)/(N-K-1)
adjusted_Rsquare
# Out:
# 0.8436467406366904

# %%
linereg.coef_ # Bita Values
# Out:
# array([-7.96191923e+01, -4.05746203e+03, -9.59446950e+01,  2.30290551e-01,
#         9.06706204e+03,  4.54976941e+03, -1.60418666e+03,  2.66955006e+03,
#         1.88735783e-09, -6.35788889e+01,  8.87846229e+03,  3.24810418e+02,
#        -7.99455345e+02, -7.29781219e+03, -1.97477217e+03, -1.28414892e+03,
#         1.07566215e+04,  5.18511867e+03,  2.02117517e+02,  1.01756604e+02,
#         1.16123326e+02,  1.60585637e+04, -7.96574973e+02,  4.61829854e+02,
#         5.09658538e+02,  1.05051635e+01, -4.83526222e+03,  4.09084310e+02,
#         8.03426761e+02, -5.51046009e+03,  1.38069740e+03, -2.55506696e+03,
#        -7.67565837e+02, -6.03577829e-01,  7.82049305e+02,  4.92630289e+00,
#        -6.24914324e-01,  3.69781077e+00, -2.41288288e+03, -1.46374858e+03,
#        -2.29535410e+03, -1.22227742e+03,  1.16775255e+01,  1.44256993e+01,
#        -7.88180601e+00,  1.82214186e+01,  9.70855201e+03,  4.16167805e+02,
# ...

# %%
linereg.intercept_ # Bita not values
# Out:
# 979403.9769158066

# %%
pred_train = linereg.predict(ppt_train_x)
pred_test = linereg.predict(ppt_test_x)

# %%
err_test = ppt_test_y - pred_test

# %%
err_test
# Out:
# 1383    -42501.516854
# 420       9183.736868
# 1029       351.782678
# 310     -17188.127880
# 1144    -16332.522357
# 689       2634.994892
# 1050    -30648.304168
# 826      13990.644521
# 138     -21232.655579
# 707      41786.078873
# 1067    -17061.948731
# 562     -11979.920180
# 674      -5711.232938
# 1160     -5890.492340
# 722       6599.936020
# 1356      1518.700861
# 952      19060.539167
# 977       8073.315563
# 331       6726.891253
# 1399    -31672.183062
# 1041     -5472.988598
# 1394     24883.047528
# 256       5947.836624
# 1010      5586.317228
# 1358      8977.444297
# 86      -14857.709391
# 1056    -31233.859325
# 832       8415.367111
# 1273     -5192.342640
# 1390     18817.823080
# 830     -22798.034033
# 912       1115.660795
# 100     -11770.960628
# 731     -36562.276765
# 737       5143.706248
# 428      -5950.502159
# 1280     13904.360194
# 1308     -4846.111060
# 616     -20018.393950
# 317      11103.948635
# 506     -13972.011349
# ...

# %%
mse = np.mean(np.square(err_test))
mse
# Out:
# 526869218.08849716

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 22953.63191498237

# %%
mape = np.mean(np.abs(err_test * 100/ppt_test_y))
mape
# Out:
# 11.484167329903272

# %%
#  Lets Check The Assumption.
#  Assumption on the train data.

# %%
err_train = ppt_train_y - pred_train
err_train
# Out:
# 939      37236.695037
# 701     -11025.468843
# 627     -19821.529570
# 141      34085.092521
# 962     -14029.767927
# 281      -1835.154681
# 71        3867.071032
# 536     -17201.775165
# 1119      9767.733407
# 145     -34682.420387
# 68        -661.317735
# 1261     19198.411868
# 673      35358.309867
# 665       7216.100822
# 1375     -7973.027899
# 981      52905.823635
# 216      -4829.804691
# 77       22406.321653
# 1033      1933.036492
# 770       4209.662101
# 612      14311.698145
# 107      20512.100668
# 1440    -10477.834300
# 960       -585.685787
# 1138    -11063.185580
# 456     -14273.258686
# 240      21289.021367
# 113      10363.642466
# 1082     -9871.500837
# 579     -12846.174739
# 762      13481.235996
# 1188     -3850.051173
# 201       1562.682879
# 1382    -25779.466767
# 394      -4769.717033
# 1013    -11635.009750
# 1087     -1914.365772
# 979       5326.951561
# 422     -11769.361680
# 1232      8384.764485
# 849      -6318.117492
# ...

# %%
np.mean(err_train)
# Out:
# -4.4125162305370453e-11

# %%
# Error shoud be normally distributed.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(err_train, '*')

# %%
plt.hist(err_train, bins=20,edgecolor = 'm');

# %%
pred_actual_df = pd.DataFrame()
pred_actual_df['Actual'] = ppt_train_y
pred_actual_df['Predict'] = pred_train

# %%
pred_actual_df1 = pd.DataFrame()
pred_actual_df1['Actual']=ppt_test_y
pred_actual_df1['predict']= pred_test

# %%
import seaborn as sns

# %%
sns.jointplot(data =pred_actual_df,x = 'Actual',y = 'Predict',kind='reg')

# %%
# remove outliers
def remove_outliers(df,col,k):
    mean = df[col].mean()
    global df1
    sd = df[col].std()
    final_list = [x for x in df[col] if (x > mean-k *sd)]
    final_list = [x for x in final_list if (x< mean + k *sd)]
    df1 = df.loc[df[col].isin(final_list)]; print(df1.shape)
    print("Number of outliers remove -->",df.shape[0] - df1.shape[0])

# %%
remove_outliers(ppt,'Sale_Price',2)
# Out:
# (1326, 78)
# Number of outliers remove --> 70
